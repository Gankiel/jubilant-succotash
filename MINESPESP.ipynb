# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Solo versiones +1.17
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1




version = '1.20.1' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

server_type = 'mohist'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

if server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

if server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

if server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

if server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/' + version

if server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version
    
if server_type == 'catserver':
    serverURL = "https://serverjars.com/api/fetchJar/modded/catserver/" + version

if server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version



jar_name = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-server-launch.jar server -mcversion $version -downloadMinecraft

elif server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

elif server_type == 'vanilla':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar vanilla.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)

# Instalar OpenJDK

version = colabconfig["server_version"]

# Ejecuta un comando en la terminal

def ejecutar_comando(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 17 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 17")

# Purga versiones anteriores de OpenJDK
ejecutar_comando('sudo apt-get purge openjdk* -y')

# Instala OpenJDK 17
ejecutar_comando('sudo apt-get install openjdk-17-jre-headless -y')

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2bQBHPEsOMgeZWsgLTkoYO393v0_6YgRDXaoRhFmonaxXSwi1" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))

elif tunnel_service == "playit":

    ! curl -SsL https://playit-cloud.github.io/ppa/key.gpg | sudo apt-key add -
    ! sudo curl -SsL -o /etc/apt/sources.list.d/playit-cloud.list https://playit-cloud.github.io/ppa/playit-cloud.list
    ! sudo apt update &>/dev/null && sudo apt install playit &>/dev/null && echo "Playit.gg installed" || echo "Failed to install playit"
    print('Starting server...')
    ! playit & java $memory_allocation $server_flags -jar $jar_name nogui

print('Iniciando servidor...')

def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

if colabconfig["server_type"] == "forge":

    version = colabconfig["server_version"]
    
    forgefiles = f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/"
    
    forgepreversion = os.listdir(forgefiles)
    
    if forgepreversion:
    
        forgeversion = forgepreversion[0]
        forgeversionchecked = forgeversion.replace(".jar", "")
        print("La versión de Forge es:", forgeversionchecked)
    
    else:
    
        print("No se encontraron archivos en el directorio Forge.")
    
    pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{forgeversionchecked}/unix_args.txt")

    if pathtoforge: # Checa si la lista no esta vacia

        path = pathtoforge[0] # Obtiene la primera ruta de la lista

        print(path)

        # !java @user_jvm_args.txt "@{path}" "$@"

    else:

        print("No se encontro el archivo unix_args.txt.")

#Si el servidor es de tipo Vanilla o paper o mohist o catserver o purpur

else:
    #Ejecuta el archivo jar del servidor
    
    # !java $memory_allocation $server_flags -jar $jar_name nogui   

# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      eula.txt	    mohist-config    server.properties
# banned-players.json  forge.jar	    mohist.jar	     spigot.yml
# bukkit.yml	     forge.jar.log  ops.json	     user_jvm_args.txt
# colabconfig.json     help.yml	    permissions.yml  usercache.json
# commands.yml	     libraries	    plugins	     usernamecache.json
# config		     logs	    run.bat	     whitelist.json
# defaultconfigs	     mods	    run.sh	     world
# OpenJDK 17 instalado correctamente
# OpenJDK 17 instalado correctamente
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 0.tcp.ngrok.io:18259
# Iniciando servidor...
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#  ███╗   ███╗  ██████╗  ██╗  ██╗ ██╗ ███████╗ ████████╗
#  ████╗ ████║ ██╔═══██╗ ██║  ██║ ██║ ██╔════╝ ╚══██╔══╝
#  ██╔████╔██║ ██║   ██║ ███████║ ██║ ███████╗    ██║
#  ██║╚██╔╝██║ ██║   ██║ ██╔══██║ ██║ ╚════██║    ██║
#  ██║ ╚═╝ ██║ ╚██████╔╝ ██║  ██║ ██║ ███████║    ██║
#  ╚═╝     ╚═╝  ╚═════╝  ╚═╝  ╚═╝ ╚═╝ ╚══════╝    ╚═╝
#
#
# Thanks for using Mohist - 1.20.1-580, Java(21.0.2) 65.0 PID: 4972
#
# Update in check...
# If you don't want to enable update check, set check_update in mohist-config/mohist.yml to false
# The latest Mohist version is 1.20.1-612 but you have 1.20.1-580. The latest version has been built on 2024-03-11 15:43:07. You should update to fix recent bugs!
# Checking libraries, please wait...
# All libraries are nice :)!
# Searching incompatible mods...
# [02:52:37 INFO]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 47.2.20, --fml.mcVersion, 1.20.1, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20230612.114412, nogui]
# [02:52:37 INFO]: ModLauncher 10.0.9+10.0.9+main.dcd20f30 starting: java version 21.0.2 by Microsoft; OS Linux arch amd64 version 6.2.0-1019-azure
# [02:52:37 INFO]: ImmediateWindowProvider not loading because launch target is forgeserver
# [02:52:37 INFO]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%23111!/ Service=ModLauncher Env=SERVER
# [02:52:38 INFO]: No dependencies to load found. Skipping!
# [02:52:39 INFO]: Launching target 'forgeserver' with arguments [nogui]
# [02:52:39 WARN]: Reference map 'playitforge.refmap.json' for playit-forge.mixins.json could not be read. If this is a development environment you can ignore this message
# [02:52:46 INFO]: Forge mod loading, version 47.2.20, for MC 1.20.1 with MCP 20230612.114412
# [02:52:46 INFO]: MinecraftForge v47.2.20 Initialized
# [02:52:46 INFO]: NeoForge v47.2.20 Initialized
# [02:52:46 INFO]: Mohist mod loading.....
# [02:52:46 INFO]: EventDispatcherRegistry initialized
# [02:52:48 INFO]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [02:52:49 INFO]: registered playit command
# [02:52:50 INFO]: Loaded 7 recipes
# [02:52:50 INFO]: Loaded 1271 advancements
# [02:52:50 INFO]: Starting minecraft server version 1.20.1
# [02:52:50 INFO]: Loading properties
# [02:52:50 INFO]: Default game type: SURVIVAL
# [02:52:50 INFO]: Generating keypair
# [02:52:51 INFO]: Starting Minecraft server on *:25565
# [02:52:51 INFO]: Using epoll channel type
# [02:52:51 WARN]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [02:52:51 WARN]: The server will make no attempt to authenticate usernames. Beware.
# [02:52:51 WARN]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [02:52:51 WARN]: To change this, set "online-mode" to "true" in the server.properties file.
# [02:52:51 INFO]: This server is running Mohist version 1.20.1-580 (MC: 1.20.1) (Implementing API version 1.20.1-R0.1-SNAPSHOT, Forge version 47.2.20, NeoForge version 47.1.79)
# [02:52:52 INFO]: Debug logging is enabled
# [02:52:52 INFO]: Server Ping Player Sample Count: 20
# [02:52:52 INFO]: Using 4 threads for Netty based IO
# [02:52:52 INFO]: Hello Plugins!
# [02:52:52 INFO]: Preparing level "world"
# [02:52:55 INFO]: Preparing start region for dimension minecraft:overworld
# [02:52:56 INFO]: Preparing spawn area: 0%
# [02:52:56 INFO]: Preparing spawn area: 0%
# [02:52:56 INFO]: Preparing spawn area: 0%
# [02:52:56 INFO]: Preparing spawn area: 0%
# [02:52:57 INFO]: Preparing spawn area: 0%
# [02:52:57 INFO]: Preparing spawn area: 0%
# [02:52:58 INFO]: Preparing spawn area: 0%
# [02:52:58 INFO]: Preparing spawn area: 4%
# [02:52:59 INFO]: Preparing spawn area: 4%
# [02:52:59 INFO]: Preparing spawn area: 30%
# [02:52:59 INFO]: Time elapsed: 4838 ms
# [02:53:00 INFO]: Preparing start region for dimension minecraft:the_nether
# [02:53:00 INFO]: Preparing spawn area: 0%
# [02:53:00 INFO]: Preparing spawn area: 0%
# [02:53:01 INFO]: Preparing spawn area: 0%
# [02:53:01 INFO]: Preparing spawn area: 3%
# [02:53:02 INFO]: Preparing spawn area: 18%
# [02:53:02 INFO]: Time elapsed: 2346 ms
# [02:53:02 INFO]: Preparing start region for dimension minecraft:the_end
# [02:53:02 INFO]: Preparing spawn area: 0%
# [02:53:02 INFO]: Preparing spawn area: 0%
# [02:53:03 INFO]: Preparing spawn area: 4%
# [02:53:03 INFO]: Preparing spawn area: 48%
# [02:53:04 INFO]: Time elapsed: 1643 ms
# [02:53:04 INFO]: [Mohist] Enabling Mohist v1.20.1
# [02:53:04 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [02:53:04 INFO]: Done (12.280s)! For help, type "help"
# [02:53:04 INFO]: Successfully initialized permission handler forge:default_handler
# [02:53:04 INFO]: Forwarding forge permission[forge:default_handler] to bukkit[mohist:permission]
# [02:53:04 INFO]: secret key found, checking
# [02:53:04 INFO]: check secret
# [02:53:05 INFO]: found minecraft java tunnel: mon-characterized.joinmc.link
# [02:53:05 INFO]: keys and tunnel setup
# [02:53:05 WARN]: Got IO error working with :control.playit.gg/2602:fbaf:810:0:0:0:0:1, error : java.net.SocketException: Network is unreachable
# [02:53:06 INFO]: request queued, waiting 1 second before resend
# [02:53:07 INFO]: request queued, waiting 1 second before resend
# [02:53:27 INFO]: got new client: NewClient{connectAddr=209.25.140.181:62995, peerAddr=189.217.208.208:55174, claimAddress=209.25.140.2:43264, claimToken=[44, 0, 60, -47, 25, -116, -75, -10, 19, -67, -39, -48, -48, -41, -122, 47, -45, 96, -72, -87, 0, 101, -17, -61, -89, 0, 0, 0, 0, 0, 7, 35, 103, 0, 0, 0, 0, 0, 47, 48, 44, 64, -72, -87, 0, 0, 0, 0, 0, 5, 0, 0, 0, 0, 0, 0, 0, 1, 0, 1, 118, -43, -21, -11, -52, -82, -46, 56, -4, 53, 34, 22, -49, -104, 94, -1], tunnelServerId=1, dataCenterId=5}
# [02:53:27 INFO]: starting tcp tunnel for client
# [02:53:27 INFO]: start connection to /209.25.140.2:43264 to claim client
# [02:53:27 INFO]: connected to tunnel server, sending claim token
# [02:53:27 INFO]: claim token sent
# [02:53:27 INFO]: connection to tunnel server has been established
# [02:53:27 INFO]: Reflect: ReflectionHelper{ServerConnection=null, LegacyPingHandler=null, MinecraftServer=class net.minecraft.server.MinecraftServer, PacketSplitter=null, PacketDecoder=class net.minecraft.network.PacketDecoder, EnumProtocolDirection=null, PacketPrepender=null, PacketEncoder=class net.minecraft.network.PacketEncoder, NetworkManagerServer=null, NetworkManager=null, HandshakeListener=null, PacketListener=interface net.minecraft.network.PacketListener}
# [02:53:27 INFO]: failed to get ServerConnection from Minecraft Server
# [02:53:27 INFO]: connecting to minecraft server at localhost/127.0.0.1:25565
# [02:53:27 INFO]: connected to local minecraft server
# [02:54:02 INFO]: got new client: NewClient{connectAddr=209.25.140.181:62995, peerAddr=189.217.208.208:55188, claimAddress=209.25.140.2:43264, claimToken=[44, 0, 60, -47, 25, -116, -75, -10, 19, -67, -39, -48, -48, -41, -108, -46, -60, -28, 104, -87, 0, 101, -17, -61, -54, 0, 0, 0, 0, 0, 7, 35, 103, 0, 0, 0, 0, 0, 47, 48, 44, -5, 104, -87, 0, 0, 0, 0, 0, 5, 0, 0, 0, 0, 0, 0, 0, 1, 0, 1, 104, 0, 24, -112, -107, 12, 36, -27, 66, 36, 9, -5, -41, -102, -112, 107], tunnelServerId=1, dataCenterId=5}
# [02:54:02 INFO]: starting tcp tunnel for client
# [02:54:02 INFO]: start connection to /209.25.140.2:43264 to claim client
# [02:54:02 INFO]: connected to tunnel server, sending claim token
# [02:54:02 INFO]: claim token sent
# [02:54:02 INFO]: connection to tunnel server has been established
# [02:54:02 INFO]: Reflect: ReflectionHelper{ServerConnection=null, LegacyPingHandler=null, MinecraftServer=class net.minecraft.server.MinecraftServer, PacketSplitter=null, PacketDecoder=class net.minecraft.network.PacketDecoder, EnumProtocolDirection=null, PacketPrepender=null, PacketEncoder=class net.minecraft.network.PacketEncoder, NetworkManagerServer=null, NetworkManager=null, HandshakeListener=null, PacketListener=interface net.minecraft.network.PacketListener}
# [02:54:02 INFO]: failed to get ServerConnection from Minecraft Server
# [02:54:02 INFO]: connecting to minecraft server at localhost/127.0.0.1:25565
# [02:54:02 INFO]: connected to local minecraft server
# [02:54:02 INFO]: jime_de_bayuwu joined the game
# [02:54:02 INFO]: jime_de_bayuwu[/127.0.0.1:49008] logged in with entity id 161 at ([world]867.0598496479571, 78.0, 1322.110991457485)
# [02:56:15 INFO]: got new client: NewClient{connectAddr=209.25.140.181:62995, peerAddr=181.236.105.152:12405, claimAddress=209.25.140.2:43784, claimToken=[44, 0, 60, -47, 25, -116, -75, -10, 19, -75, -20, 105, -104, 48, 117, -128, 40, 73, 25, -85, 8, 101, -17, -60, 79, 0, 0, 0, 0, 0, 7, 35, 103, 0, 0, 0, 0, 0, 47, 48, 44, -24, 25, -85, 8, 0, 0, 0, 0, 6, 0, 0, 0, 0, 0, 0, 0, 1, 0, 1, 34, 31, -52, 42, -37, 49, -64, -120, -18, -113, -110, 69, -64, -128, 98, -32], tunnelServerId=1, dataCenterId=6}
# [02:56:15 INFO]: starting tcp tunnel for client
# [02:56:15 INFO]: start connection to /209.25.140.2:43784 to claim client
# [02:56:15 INFO]: connected to tunnel server, sending claim token
# [02:56:15 INFO]: claim token sent
# [02:56:15 INFO]: connection to tunnel server has been established
# [02:56:15 INFO]: Reflect: ReflectionHelper{ServerConnection=null, LegacyPingHandler=null, MinecraftServer=class net.minecraft.server.MinecraftServer, PacketSplitter=null, PacketDecoder=class net.minecraft.network.PacketDecoder, EnumProtocolDirection=null, PacketPrepender=null, PacketEncoder=class net.minecraft.network.PacketEncoder, NetworkManagerServer=null, NetworkManager=null, HandshakeListener=null, PacketListener=interface net.minecraft.network.PacketListener}
# [02:56:15 INFO]: failed to get ServerConnection from Minecraft Server
# [02:56:15 INFO]: connecting to minecraft server at localhost/127.0.0.1:25565
# [02:56:15 INFO]: connected to local minecraft server
# [02:56:17 INFO]: got new client: NewClient{connectAddr=209.25.140.181:62995, peerAddr=181.236.105.152:12406, claimAddress=209.25.140.2:43784, claimToken=[44, 0, 60, -47, 25, -116, -75, -10, 19, -75, -20, 105, -104, 48, 118, -25, -82, 8, 79, -85, 8, 101, -17, -60, 81, 0, 0, 0, 0, 0, 7, 35, 103, 0, 0, 0, 0, 0, 47, 48, 44, -33, 79, -85, 8, 0, 0, 0, 0, 6, 0, 0, 0, 0, 0, 0, 0, 1, 0, 1, 45, 52, 44, -81, 27, 19, 18, -14, 13, 124, -47, -93, 7, -94, 108, -40], tunnelServerId=1, dataCenterId=6}
# [02:56:17 INFO]: starting tcp tunnel for client
# [02:56:17 INFO]: start connection to /209.25.140.2:43784 to claim client
# [02:56:17 INFO]: connected to tunnel server, sending claim token
# [02:56:17 INFO]: claim token sent
# [02:56:17 INFO]: connection to tunnel server has been established
# [02:56:17 INFO]: Reflect: ReflectionHelper{ServerConnection=null, LegacyPingHandler=null, MinecraftServer=class net.minecraft.server.MinecraftServer, PacketSplitter=null, PacketDecoder=class net.minecraft.network.PacketDecoder, EnumProtocolDirection=null, PacketPrepender=null, PacketEncoder=class net.minecraft.network.PacketEncoder, NetworkManagerServer=null, NetworkManager=null, HandshakeListener=null, PacketListener=interface net.minecraft.network.PacketListener}
# [02:56:17 INFO]: failed to get ServerConnection from Minecraft Server
# [02:56:17 INFO]: connecting to minecraft server at localhost/127.0.0.1:25565
# [02:56:17 INFO]: connected to local minecraft server
# [02:56:18 INFO]: Gabi_21 joined the game
# [02:56:18 INFO]: Gabi_21[/127.0.0.1:50680] logged in with entity id 760 at ([world]854.4821326608316, 78.0, 1320.5440402929748)
# [02:56:38 INFO]: <jime_de_bayuwu> donde estas amor
# [02:56:49 INFO]: <Gabi_21> te carga bien?
# [02:56:54 INFO]: <jime_de_bayuwu> si
# [02:57:09 INFO]: send keep alive
# [02:57:09 INFO]: <Gabi_21> ahora si podemos ir por oceano
# [02:57:23 INFO]: <jime_de_bayuwu> creo q si
# [03:01:10 INFO]: send keep alive
# [03:02:14 INFO]: <jime_de_bayuwu> amor seguro q es x aca
# [03:02:26 INFO]: <Gabi_21> encontramos una mansion
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [03:02:30 INFO]: <Gabi_21> pero es de los malos
# [03:02:42 INFO]: <jime_de_bayuwu> si :c
# [03:02:54 INFO]: <jime_de_bayuwu> toma cap de las cordenadas
# [03:03:01 INFO]: <Gabi_21> ya
# [03:03:02 INFO]: <jime_de_bayuwu> para ir luego
# [03:03:08 INFO]: <Gabi_21> si
# [03:03:10 INFO]: <Gabi_21> ahora es otra aldea
# [03:03:24 INFO]: <jime_de_bayuwu> amor me amas :c
# [03:03:29 INFO]: <Gabi_21> siiiiiiiiii
# [03:03:36 INFO]: <jime_de_bayuwu> meno :)
# [03:03:40 INFO]: <Gabi_21> uwu
# [03:04:30 INFO]: <jime_de_bayuwu> no me importa q seas m,ayor q yo
# [03:05:05 INFO]: <Gabi_21> en seriow
# [03:05:09 INFO]: <Gabi_21> :0
# [03:05:11 INFO]: send keep alive
# [03:05:13 INFO]: <jime_de_bayuwu> ujum
# [03:05:27 INFO]: <jime_de_bayuwu> mientras seas solo mio uwu
# [03:05:36 INFO]: <Gabi_21> si obvio
# [03:05:41 INFO]: <Gabi_21> y tu mia
# [03:05:42 INFO]: <jime_de_bayuwu> sisis
# [03:05:48 INFO]: <jime_de_bayuwu> siempre
# [03:06:20 INFO]: <Gabi_21> ya has estado con otros mayores?
# [03:06:29 INFO]: <jime_de_bayuwu> mmm de 15
# [03:06:33 WARN]: Boat (vehicle of jime_de_bayuwu) moved wrongly! 0.5617724229003477
# [03:06:33 INFO]: <jime_de_bayuwu> nomas
# [03:07:14 INFO]: <Gabi_21> y tu tienes 14
# [03:07:19 INFO]: <jime_de_bayuwu> tu eres el mas grande
# [03:07:29 INFO]: <jime_de_bayuwu> sisis los acabo de cumplir
# [03:07:35 INFO]: <jime_de_bayuwu> el 21
# [03:07:46 INFO]: <Gabi_21> hiciste fiesta?
# [03:07:53 INFO]: <jime_de_bayuwu> no :c
# [03:08:32 INFO]: <jime_de_bayuwu> oye
# [03:08:35 INFO]: <Gabi_21> cuando te vea hacemos fiesta
# [03:08:41 INFO]: <jime_de_bayuwu> sisis
# [03:08:45 INFO]: <Gabi_21> dime
# [03:09:12 INFO]: send keep alive
# [03:09:32 INFO]: <jime_de_bayuwu> de echo antes te odiaba xq sarai no me hacia caso pero ahora te amo <3 dicen qq los q se odian se aman
# [03:09:52 INFO]: <Gabi_21> te refieres cuando andaba con sarai
# [03:10:05 INFO]: <jime_de_bayuwu> anduvieron :0
# [03:10:25 INFO]: <Gabi_21> si pero eso quedo en el pasado
# [03:10:33 INFO]: <jime_de_bayuwu> y si jaja
# [03:10:33 INFO]: <Gabi_21> me odiabas por eso?¡
# [03:10:43 INFO]: <Gabi_21> tranqui
# [03:10:47 INFO]: <jime_de_bayuwu> no me dieron celos :c
# [03:10:48 INFO]: <Gabi_21> no pasa nada
# [03:10:53 INFO]: <Gabi_21> celos pq
# [03:11:05 INFO]: <jime_de_bayuwu> xq andubiste con ella :c
# [03:11:13 INFO]: <Gabi_21> ella me remplazo
# [03:11:18 INFO]: <Gabi_21> ella ya no me importa
# [03:11:25 INFO]: <jime_de_bayuwu> si :c
# [03:11:33 INFO]: <jime_de_bayuwu> y yo :c
# [03:11:40 INFO]: <Gabi_21> tu si bb tu eres todo
# [03:11:46 INFO]: <Gabi_21> tueres mejor q ella
# [03:11:52 INFO]: <jime_de_bayuwu> seguro :c
# [03:11:55 INFO]: <Gabi_21> si seguro
# [03:12:07 INFO]: <Gabi_21> ahora tu eres mia y yo tuyo
# [03:12:10 INFO]: <jime_de_bayuwu> te aMOOOOOOO:3
# [03:12:23 INFO]: <Gabi_21> yo maaaaaaaaaas
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [03:12:30 INFO]: <jime_de_bayuwu> muaa
# [03:12:33 INFO]: <Gabi_21> alv
# [03:12:35 INFO]: <Gabi_21> el templo
# [03:12:36 INFO]: <Gabi_21> acuatico
# [03:12:46 INFO]: <jime_de_bayuwu> xd
# [03:12:48 INFO]: <Gabi_21> esta ahi abajo
# [03:12:51 INFO]: <Gabi_21> guarde cordenadas xd
# [03:13:00 INFO]: <jime_de_bayuwu> encontramos todo menos la casa
# [03:13:04 INFO]: <Gabi_21> hemos encontrado de todo menos otra aldea
# [03:13:08 INFO]: <Gabi_21> la casa si se donde esta
# [03:13:10 INFO]: <Gabi_21> miraaaa
# [03:13:12 INFO]: <Gabi_21> ora aldea
# [03:13:13 INFO]: send keep alive
# [03:13:17 INFO]: <jime_de_bayuwu> sisis
# [03:13:23 INFO]: <Gabi_21> q suerte
# [03:16:15 INFO]: jime_de_bayuwu has made the advancement [What a Deal!]
# [03:17:04 INFO]: <jime_de_bayuwu> tas bonito
# [03:17:12 INFO]: <Gabi_21> bueno, ya podemos hacer los cultivos, seguimos explorando o volvemosa casa?
# [03:17:14 INFO]: send keep alive
# [03:17:15 INFO]: <Gabi_21> ytu mas bonita
# [03:17:25 INFO]: <jime_de_bayuwu> como quieras jeje
# [03:17:28 INFO]: <Gabi_21> t di
# [03:17:30 INFO]: <Gabi_21> tu dio
# [03:17:31 INFO]: <Gabi_21> di
# [03:17:57 INFO]: <jime_de_bayuwu> hacemos nuestra casita y vamos despues a una mina
# [03:18:06 INFO]: <Gabi_21> ya la csa aesta hecha xd
# [03:18:08 INFO]: <Gabi_21> te acuerdas
# [03:18:13 INFO]: <jime_de_bayuwu> sisis
# [03:18:22 INFO]: <Gabi_21> bueno, vamos y de paso hago los cultivos
# [03:18:22 INFO]: <jime_de_bayuwu> pero la decoramos mas +
# [03:18:28 INFO]: <Gabi_21> tienes el bote?
# [03:18:34 INFO]: <jime_de_bayuwu> si
# [03:19:57 INFO]: <Gabi_21> y ya lo has hecho con mayores?
# [03:20:06 INFO]: <jime_de_bayuwu> ujum
# [03:20:15 INFO]: <Gabi_21> con kine
# [03:20:17 INFO]: <Gabi_21> kien
# [03:20:38 INFO]: <jime_de_bayuwu> con uno k se llama miguel tiene 15
# [03:20:48 INFO]: <Gabi_21> y lo haces con el todavia?
# [03:20:53 INFO]: <jime_de_bayuwu> fue el unico y el ultimo
# [03:21:00 INFO]: <jime_de_bayuwu> ya no
# [03:21:08 INFO]: <Gabi_21> porq
# [03:21:15 INFO]: send keep alive
# [03:21:44 INFO]: <jime_de_bayuwu> xq el lo hace con cualquiera y me da asco eso y aparte xq ya te tengo a ti
# [03:21:56 INFO]: <Gabi_21> ps si :3
# [03:22:03 INFO]: <Gabi_21> aaa y como te enteraste
# [03:22:06 INFO]: <Gabi_21> que lo hacia con cualqueira
# [03:22:09 INFO]: <jime_de_bayuwu> y tu
# [03:22:15 INFO]: <jime_de_bayuwu> me lo dijo alguien
# [03:22:23 INFO]: <Gabi_21> yo no lo he hecho con nadie
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [03:22:30 INFO]: <jime_de_bayuwu> x mensaje
# [03:22:31 INFO]: <Gabi_21> pero quiero contigo
# [03:22:42 INFO]: <Gabi_21> quiero hacerlo contigo x mensaje
# [03:23:03 INFO]: <jime_de_bayuwu> pero x mensaje lo hisiste con sarai :v
# [03:23:29 INFO]: <Gabi_21> na
# [03:23:37 INFO]: <jime_de_bayuwu> seguro ._.
# [03:23:41 INFO]: <Gabi_21> seguro
# [03:23:45 INFO]: <Gabi_21> ella no tenia tiempo para mi
# [03:23:49 INFO]: <jime_de_bayuwu> meno
# [03:24:03 INFO]: <jime_de_bayuwu> pero si tdo el dia estaba libre
# [03:24:07 INFO]: <jime_de_bayuwu> :v
# [03:24:14 INFO]: <Gabi_21> pues medecia siempre que estaba ocupada
# [03:24:50 INFO]: <Gabi_21> y con miguel lo hiciste x mensaje?
# [03:24:51 INFO]: <jime_de_bayuwu> una vez dijo q solo te queria xq le comprabas skines en su juego en el lol
# [03:25:11 INFO]: <jime_de_bayuwu> no con el no:v
# [03:25:17 INFO]: send keep alive
# [03:25:19 INFO]: <Gabi_21> por donde lo hiciste entonces
# [03:25:30 INFO]: <jime_de_bayuwu> en persona jaja
# [03:25:38 INFO]: <Gabi_21> en donde en tu casa?
# [03:25:43 INFO]: <jime_de_bayuwu> si
# [03:26:23 INFO]: <Gabi_21> cuantas veces lo hiciste con el?
# [03:26:31 INFO]: <jime_de_bayuwu> la nt no se
# [03:26:44 INFO]: <Gabi_21> masomenos cuanto
# [03:27:00 INFO]: <jime_de_bayuwu> ala semana o en todo el tiempi
# [03:27:06 INFO]: <Gabi_21> a la semana
# [03:27:19 INFO]: <jime_de_bayuwu> unas 5 o 6
# [03:27:27 INFO]: <Gabi_21> a que hora lo hacian
# [03:27:39 INFO]: <jime_de_bayuwu> alas 7 o 8
# [03:27:47 INFO]: <Gabi_21> y no tenias miedo de que te embarazara
# [03:27:57 INFO]: <jime_de_bayuwu> usabamos condon
# [03:28:07 INFO]: <Gabi_21> nunca lo hicieron sin condon?
# [03:28:13 INFO]: <jime_de_bayuwu> no se
# [03:28:16 INFO]: <jime_de_bayuwu> :v
# [03:28:21 INFO]: <jime_de_bayuwu> no me acuerdo
# [03:28:40 INFO]: <Gabi_21> te gustaba?
# [03:28:48 INFO]: <jime_de_bayuwu> aveces
# [03:29:18 INFO]: send keep alive
# [03:29:28 INFO]: <Gabi_21> como hacias para que no se dieran cuenta en tu casa
# [03:29:37 INFO]: <jime_de_bayuwu> oooo
# [03:29:40 INFO]: <jime_de_bayuwu> no se
# [03:29:45 INFO]: <jime_de_bayuwu> solo pasaba
# [03:30:57 INFO]: <Gabi_21> y x mensaje lo has hecho?
# [03:31:02 INFO]: <jime_de_bayuwu> y q te dijo sarai cuando terminaron :v
# [03:31:08 INFO]: <jime_de_bayuwu> nop
# [03:31:15 INFO]: <Gabi_21> ella nunca me dijo nada
# [03:31:17 INFO]: <jime_de_bayuwu> solo contigo
# [03:31:28 INFO]: <jime_de_bayuwu> tons como te diste cuenta
# [03:31:40 INFO]: <Gabi_21> cuando ella empezo la uni
# [03:31:43 INFO]: <Gabi_21> dejo de hablarme
# [03:31:55 INFO]: <Gabi_21> me hablaba 1 vez al mes o algo asi
# [03:32:08 INFO]: <jime_de_bayuwu> nmms y q le dijiste
# [03:32:22 INFO]: <Gabi_21> le pregunte pq
# [03:32:28 INFO]: <Gabi_21> y dijo que estaba ocupada
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [03:32:33 INFO]: <Gabi_21> y que no tenia tiempo para hablar
# [03:32:38 INFO]: <jime_de_bayuwu> :0
# [03:32:45 INFO]: <Gabi_21> entonces dije que la esperaba y eso
# [03:33:08 INFO]: <jime_de_bayuwu> como supiste q andaba con su nv
# [03:33:19 INFO]: send keep alive
# [03:33:34 INFO]: <Gabi_21> porque se habia puesto de nombre de pareja con el en el lol
# [03:33:48 INFO]: <jime_de_bayuwu> :0
# [03:33:49 INFO]: <Gabi_21> y me dijo que solo era porque eran equipo
# [03:33:57 INFO]: <Gabi_21> como si yo fuera bobo a creerme esa mentirota
# [03:34:05 INFO]: <jime_de_bayuwu> y como terminaron
# [03:34:37 INFO]: <Gabi_21> ella me fue infiel y en vez de terminarme me dejo de hablar
# [03:34:53 INFO]: <jime_de_bayuwu> :0
# [03:35:00 INFO]: <Gabi_21> me fue infiel con el novio que tiene ahora
# [03:35:03 INFO]: <jime_de_bayuwu> lo nego o lo acepto
# [03:35:13 INFO]: <Gabi_21> lo nego siempre sacaba excusas
# [03:35:19 INFO]: <Gabi_21> pero ya era obvio
# [03:35:22 INFO]: <jime_de_bayuwu> nmms
# [03:35:35 INFO]: <Gabi_21> y entonces yo tambien me aburri de esperarla y aparte que me estaba poniendo los cuernos de forma descarada
# [03:35:50 INFO]: <jime_de_bayuwu> de vdd la querias para algo bien
# [03:35:52 INFO]: <Gabi_21> luego de repente puso su foto con el en su whatsapp que le besaba la mejilla
# [03:36:04 INFO]: <Gabi_21> y pues la borre de mis contactos y pues ya me olvide de ella
# [03:36:05 INFO]: <jime_de_bayuwu> :0
# [03:36:20 INFO]: <Gabi_21> que sea feliz con su novio igual no le quita lo infiel
# [03:36:31 INFO]: <jime_de_bayuwu> aver cuenta
# [03:36:36 INFO]: <Gabi_21> pues ya te conte
# [03:36:44 INFO]: <jime_de_bayuwu> engaña al nuevo novio
# [03:36:48 INFO]: <Gabi_21> no
# [03:36:51 INFO]: <Gabi_21> no se
# [03:36:55 INFO]: <jime_de_bayuwu> :0
# [03:36:55 INFO]: <Gabi_21> me engaño a mi
# [03:37:02 INFO]: <Gabi_21> por eso es infiel
# [03:37:20 INFO]: send keep alive
# [03:37:21 INFO]: <jime_de_bayuwu> amor :c yo sin te quiero para algo bien te amo mucho
# [03:37:26 INFO]: <Gabi_21> si me hubiera terminado ok pero no me termino, me reemplazo
# [03:37:41 INFO]: <Gabi_21> no me dijo ni adios ni nada sino que desaparecio
# [03:37:42 INFO]: <jime_de_bayuwu> :0 nmms eso duele mas
# [03:37:51 INFO]: <jime_de_bayuwu> :c
# [03:37:55 INFO]: <Gabi_21> si eso dolio pero ya no me importa
# [03:38:02 INFO]: <jime_de_bayuwu> amor
# [03:38:24 INFO]: <Gabi_21> yo le daba skins en lol porque la amaba y queria algo bien con ella pero bueno ya me dijiste
# [03:38:29 INFO]: <Gabi_21> que ella solo me amaba porque le daba skins
# [03:38:37 INFO]: <Gabi_21> osea no le importaba lo que sentia
# [03:38:47 INFO]: <Gabi_21> que feo pero bueno
# [03:38:47 INFO]: <jime_de_bayuwu> yo si te quiero para algo bien y te amo <3 prometo cuidarte
# [03:38:58 INFO]: <Gabi_21> esta bien amor yo mas, tranquila
# [03:39:03 INFO]: <Gabi_21> ya sarai no me importa
# [03:39:06 INFO]: <Gabi_21> no existe para im
# [03:39:08 INFO]: <Gabi_21> mi
# [03:39:13 INFO]: <jime_de_bayuwu> amor curare tus eridas
# [03:39:17 INFO]: <Gabi_21> asi como ella se olvido de mi yo me olvide de ella
# [03:39:23 INFO]: <jime_de_bayuwu> <3 te amo
# [03:39:26 INFO]: <Gabi_21> yo mas
# [03:39:37 INFO]: <jime_de_bayuwu> ya vamos a casa
# [03:39:45 INFO]: <Gabi_21> me daras la prueba de amor?
# [03:39:53 INFO]: <jime_de_bayuwu> va
# [03:40:01 INFO]: <Gabi_21> si sabes a lo que me refiero no
# [03:40:06 INFO]: <jime_de_bayuwu> si jerje
# [03:40:23 INFO]: <Gabi_21> no quieres por mensaje?
# [03:40:42 INFO]: <jime_de_bayuwu> es k no tengo cel :c
# [03:40:59 INFO]: <Gabi_21> pense que no te regañaban por tener tu lap
# [03:41:21 INFO]: send keep alive
# [03:41:35 INFO]: <jime_de_bayuwu> pero como voy ala escuela tengo q dormirme temprano :c
# [03:42:03 INFO]: <Gabi_21> y se dan cuenta que tienes la lap prendida?
# [03:42:10 INFO]: <jime_de_bayuwu> ps si
# [03:42:18 INFO]: <jime_de_bayuwu> la tengo en la sala
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [03:42:32 INFO]: <Gabi_21> pense que la tenias en tu cuarto
# [03:42:41 INFO]: <jime_de_bayuwu> andan remodelando
# [03:42:44 INFO]: <jime_de_bayuwu> la casa
# [03:42:47 INFO]: <jime_de_bayuwu> x eso
# [03:42:53 INFO]: <Gabi_21> y en donde duermes tu
# [03:43:07 INFO]: <jime_de_bayuwu> en la sala
# [03:43:19 INFO]: <Gabi_21> ooh ya
# [03:43:21 INFO]: <jime_de_bayuwu> asta q este mi cuarto
# [03:43:30 INFO]: <Gabi_21> y se demora mucho tu cuarto?
# [03:43:38 INFO]: <jime_de_bayuwu> nop
# [03:43:43 INFO]: <Gabi_21> cuantos dias
# [03:43:49 INFO]: <jime_de_bayuwu> 15
# [03:43:53 INFO]: <Gabi_21> esta bien
# [03:44:00 INFO]: <jime_de_bayuwu> sisis
# [03:44:20 INFO]: <Gabi_21> y fotos no me puedes mandar como prueba?
# [03:44:50 INFO]: <jime_de_bayuwu> prueba de k amor
# [03:44:56 INFO]: <Gabi_21> como prueba de amor
# [03:44:58 INFO]: <Gabi_21> fotitos
# [03:45:05 INFO]: <jime_de_bayuwu> no tengo :c
# [03:45:12 INFO]: <Gabi_21> cuando tengas el cel de tu papa
# [03:45:13 INFO]: <jime_de_bayuwu> en la lap
# [03:45:19 INFO]: <jime_de_bayuwu> okis
# [03:45:23 INFO]: send keep alive
# [03:45:26 INFO]: <Gabi_21> pero fotitos ya sabes
# [03:45:31 INFO]: <jime_de_bayuwu> si
# [03:45:40 INFO]: <Gabi_21> si sabes que tipo de fotos verdad
# [03:45:57 INFO]: <jime_de_bayuwu> asi es
# [03:46:01 INFO]: <Gabi_21> a ver
# [03:46:02 INFO]: <Gabi_21> que tipo
# [03:46:07 INFO]: <jime_de_bayuwu> aca
# [03:46:16 INFO]: <jime_de_bayuwu> asi+
# [03:46:22 INFO]: <jime_de_bayuwu> sin nd
# [03:46:25 INFO]: <Gabi_21> si
# [03:46:26 INFO]: <Gabi_21> asi
# [03:46:31 INFO]: <Gabi_21> me vas adar?
# [03:46:33 INFO]: <jime_de_bayuwu> ovio
# [03:46:38 INFO]: <Gabi_21> mañana va?
# [03:46:38 INFO]: <jime_de_bayuwu> sisis
# [03:46:45 INFO]: <jime_de_bayuwu> sipi
# [03:46:48 INFO]: <Gabi_21> ok las espero
# [03:46:50 INFO]: <Gabi_21> mua
# [03:46:54 INFO]: <jime_de_bayuwu> mua
# [03:47:50 INFO]: <jime_de_bayuwu> <3
# [03:47:57 INFO]: <Gabi_21> por donde me las vas a mandar bb
# [03:48:03 INFO]: <jime_de_bayuwu> insta
# [03:49:23 INFO]: <jime_de_bayuwu> perdon bb
# [03:49:24 INFO]: send keep alive
# [03:49:27 INFO]: <Gabi_21> tranqui
# [03:49:56 INFO]: <Gabi_21> oki las espero por insta
# [03:50:04 INFO]: <jime_de_bayuwu> sisis+
# [03:50:49 INFO]: jime_de_bayuwu has made the advancement [Acquire Hardware]
# [03:51:14 INFO]: <jime_de_bayuwu> voy x aguaa
# [03:51:21 INFO]: <Gabi_21> okeiu
# [03:52:10 WARN]: jime_de_bayuwu was kicked for floating too long!
# [03:52:10 INFO]: jime_de_bayuwu lost connection: Flying is not enabled on this server
# [03:52:10 INFO]: jime_de_bayuwu left the game.
# [03:52:11 WARN]: handleDisconnection() called twice
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [03:52:40 INFO]: got new client: NewClient{connectAddr=209.25.140.181:62995, peerAddr=189.217.208.208:59406, claimAddress=209.25.140.2:43264, claimToken=[44, 0, 60, -47, 25, -116, -75, -10, 19, -67, -39, -48, -48, -24, 14, 72, 73, 117, 22, -87, 0, 101, -17, -47, -120, 0, 0, 0, 0, 0, 7, 35, 103, 0, 0, 0, 0, 0, 47, 48, 44, 96, 22, -87, 0, 0, 0, 0, 0, 5, 0, 0, 0, 0, 0, 0, 0, 1, 0, 1, -2, -36, -53, 31, -107, -14, -58, -90, -15, -70, -79, -59, -12, 78, -48, -56], tunnelServerId=1, dataCenterId=5}
# [03:52:40 INFO]: starting tcp tunnel for client
# [03:52:40 INFO]: start connection to /209.25.140.2:43264 to claim client
# [03:52:40 INFO]: connected to tunnel server, sending claim token
# [03:52:40 INFO]: claim token sent
# [03:52:40 INFO]: connection to tunnel server has been established
# [03:52:40 INFO]: Reflect: ReflectionHelper{ServerConnection=null, LegacyPingHandler=null, MinecraftServer=class net.minecraft.server.MinecraftServer, PacketSplitter=null, PacketDecoder=class net.minecraft.network.PacketDecoder, EnumProtocolDirection=null, PacketPrepender=null, PacketEncoder=class net.minecraft.network.PacketEncoder, NetworkManagerServer=null, NetworkManager=null, HandshakeListener=null, PacketListener=interface net.minecraft.network.PacketListener}
# [03:52:40 INFO]: failed to get ServerConnection from Minecraft Server
# [03:52:40 INFO]: connecting to minecraft server at localhost/127.0.0.1:25565
# [03:52:40 INFO]: connected to local minecraft server
# [03:52:40 INFO]: jime_de_bayuwu joined the game
# [03:52:40 INFO]: jime_de_bayuwu[/127.0.0.1:43908] logged in with entity id 28986 at ([world]133.9599270297237, 72.55383808212872, -104.07910812424458)
# [03:53:25 INFO]: send keep alive
# [03:53:39 INFO]: <jime_de_bayuwu> amorrr
# [03:54:23 INFO]: <jime_de_bayuwu> amor
# [03:55:37 INFO]: <jime_de_bayuwu> me perdi
# [03:56:19 INFO]: <Gabi_21> te traigo?
# [03:56:27 INFO]: <jime_de_bayuwu> si
# [03:56:35 INFO]: Gabi_21 issued server command: /tp jime_de_bayuwu Gabi_21
# [03:56:35 INFO]: [Gabi_21: Teleported jime_de_bayuwu to Gabi_21]
# [03:57:26 INFO]: send keep alive
# [03:58:14 INFO]: <jime_de_bayuwu> ya hy agua infinita
# [03:59:11 INFO]: <jime_de_bayuwu> t amo+
# [03:59:40 INFO]: <Gabi_21> yo mas
# [04:00:20 INFO]: <jime_de_bayuwu> toma
# [04:00:32 INFO]: <Gabi_21> gracias bb
# [04:00:39 INFO]: <jime_de_bayuwu> mua bb
# [04:01:27 INFO]: send keep alive
# [04:01:58 INFO]: Gabi_21 issued server command: /give Gabi_21 minecraft:carrot 10
# [04:01:58 INFO]: [Gabi_21: Gave 10 [Carrot] to Gabi_21]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [04:05:29 INFO]: send keep alive
# [04:06:50 INFO]: <jime_de_bayuwu> muaa
# [04:06:53 INFO]: <jime_de_bayuwu> bbs
# [04:06:59 INFO]: <Gabi_21> muaaaaaaaaaa
# [04:07:29 INFO]: Gabi_21 has made the advancement [A Seedy Place]
# [04:07:51 INFO]: jime_de_bayuwu has made the advancement [Isn't It Iron Pick]
# [04:09:31 INFO]: send keep alive
# [04:09:48 INFO]: <jime_de_bayuwu> zzzz
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [04:13:09 INFO]: <jime_de_bayuwu> q mal pedo la neta
# [04:13:17 INFO]: <jime_de_bayuwu> de lo de sarai
# [04:13:17 INFO]: <Gabi_21> que cosa
# [04:13:24 INFO]: <jime_de_bayuwu> se paso alch
# [04:13:25 INFO]: <Gabi_21> ya no importa
# [04:13:32 INFO]: send keep alive
# [04:15:05 WARN]: An exceptionCaught() event was fired, and it reached at the tail of the pipeline. It usually means the last handler in the pipeline did not handle the exception.
# java.net.SocketException: Connection reset
# 	at sun.nio.ch.SocketChannelImpl.throwConnectionReset(SocketChannelImpl.java:401) ~[?:?]
# 	at sun.nio.ch.SocketChannelImpl.read(SocketChannelImpl.java:434) ~[?:?]
# 	at io.netty.buffer.PooledByteBuf.setBytes(PooledByteBuf.java:258) ~[netty-buffer-4.1.82.Final.jar%23166!/:4.1.82.Final]
# 	at io.netty.buffer.AbstractByteBuf.writeBytes(AbstractByteBuf.java:1132) ~[netty-buffer-4.1.82.Final.jar%23166!/:4.1.82.Final]
# 	at io.netty.channel.socket.nio.NioSocketChannel.doReadBytes(NioSocketChannel.java:357) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:151) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:788) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:724) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:650) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:562) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997) ~[netty-common-4.1.82.Final.jar%23168!/:4.1.82.Final]
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74) ~[netty-common-4.1.82.Final.jar%23168!/:4.1.82.Final]
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30) ~[netty-common-4.1.82.Final.jar%23168!/:4.1.82.Final]
# 	at java.lang.Thread.run(Thread.java:1583) [?:?]
# [04:15:05 WARN]: failed to send data to tunnel
# [04:15:05 INFO]: jime_de_bayuwu lost connection: Disconnected
# [04:15:05 INFO]: jime_de_bayuwu left the game
# [04:15:37 INFO]: got new client: NewClient{connectAddr=209.25.140.181:62995, peerAddr=189.217.208.208:56581, claimAddress=209.25.140.2:43264, claimToken=[44, 0, 60, -47, 25, -116, -75, -10, 19, -67, -39, -48, -48, -35, 5, 104, 57, 102, 88, -87, 0, 101, -17, -42, -23, 0, 0, 0, 0, 0, 7, 35, 103, 0, 0, 0, 0, 0, 47, 48, 44, -112, 88, -87, 0, 0, 0, 0, 0, 5, 0, 0, 0, 0, 0, 0, 0, 1, 0, 1, 10, 45, -31, 39, 40, -47, -99, 23, -42, -112, 17, -68, 108, -35, -22, 84], tunnelServerId=1, dataCenterId=5}
# [04:15:37 INFO]: starting tcp tunnel for client
# [04:15:37 INFO]: start connection to /209.25.140.2:43264 to claim client
# [04:15:37 INFO]: connected to tunnel server, sending claim token
# [04:15:37 INFO]: claim token sent
# [04:15:37 INFO]: connection to tunnel server has been established
# [04:15:37 INFO]: Reflect: ReflectionHelper{ServerConnection=null, LegacyPingHandler=null, MinecraftServer=class net.minecraft.server.MinecraftServer, PacketSplitter=null, PacketDecoder=class net.minecraft.network.PacketDecoder, EnumProtocolDirection=null, PacketPrepender=null, PacketEncoder=class net.minecraft.network.PacketEncoder, NetworkManagerServer=null, NetworkManager=null, HandshakeListener=null, PacketListener=interface net.minecraft.network.PacketListener}
# [04:15:37 INFO]: failed to get ServerConnection from Minecraft Server
# [04:15:37 INFO]: connecting to minecraft server at localhost/127.0.0.1:25565
# [04:15:37 INFO]: connected to local minecraft server
# [04:15:37 INFO]: jime_de_bayuwu joined the game
# [04:15:37 INFO]: jime_de_bayuwu[/127.0.0.1:54152] logged in with entity id 33698 at ([world]7.527507015228775, 75.0, -11.27882476463371)
# [04:16:30 INFO]: <jime_de_bayuwu> pwerdon me saco
# [04:16:41 INFO]: <Gabi_21> tranqui bb
# [04:17:17 WARN]: An exceptionCaught() event was fired, and it reached at the tail of the pipeline. It usually means the last handler in the pipeline did not handle the exception.
# java.net.SocketException: Connection reset
# 	at sun.nio.ch.SocketChannelImpl.throwConnectionReset(SocketChannelImpl.java:401) ~[?:?]
# 	at sun.nio.ch.SocketChannelImpl.read(SocketChannelImpl.java:434) ~[?:?]
# 	at io.netty.buffer.PooledByteBuf.setBytes(PooledByteBuf.java:258) ~[netty-buffer-4.1.82.Final.jar%23166!/:4.1.82.Final]
# 	at io.netty.buffer.AbstractByteBuf.writeBytes(AbstractByteBuf.java:1132) ~[netty-buffer-4.1.82.Final.jar%23166!/:4.1.82.Final]
# 	at io.netty.channel.socket.nio.NioSocketChannel.doReadBytes(NioSocketChannel.java:357) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:151) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:788) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:724) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:650) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:562) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997) ~[netty-common-4.1.82.Final.jar%23168!/:4.1.82.Final]
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74) ~[netty-common-4.1.82.Final.jar%23168!/:4.1.82.Final]
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30) ~[netty-common-4.1.82.Final.jar%23168!/:4.1.82.Final]
# 	at java.lang.Thread.run(Thread.java:1583) [?:?]
# [04:17:17 WARN]: failed to send data to tunnel
# [04:17:17 INFO]: jime_de_bayuwu lost connection: Disconnected
# [04:17:17 INFO]: jime_de_bayuwu left the game
# [04:17:34 INFO]: send keep alive
# [04:18:26 INFO]: got new client: NewClient{connectAddr=209.25.140.181:62995, peerAddr=189.217.208.208:56596, claimAddress=209.25.140.2:43264, claimToken=[44, 0, 60, -47, 25, -116, -75, -10, 19, -67, -39, -48, -48, -35, 20, -48, 28, -14, -3, -87, 0, 101, -17, -41, -110, 0, 0, 0, 0, 0, 7, 35, 103, 0, 0, 0, 0, 0, 47, 48, 44, -89, -3, -87, 0, 0, 0, 0, 0, 5, 0, 0, 0, 0, 0, 0, 0, 1, 0, 1, 48, -56, 97, -47, -30, -40, 84, 92, 81, 46, -26, -96, -53, 52, 32, -117], tunnelServerId=1, dataCenterId=5}
# [04:18:26 INFO]: starting tcp tunnel for client
# [04:18:26 INFO]: start connection to /209.25.140.2:43264 to claim client
# [04:18:26 INFO]: connected to tunnel server, sending claim token
# [04:18:26 INFO]: claim token sent
# [04:18:26 INFO]: connection to tunnel server has been established
# [04:18:26 INFO]: Reflect: ReflectionHelper{ServerConnection=null, LegacyPingHandler=null, MinecraftServer=class net.minecraft.server.MinecraftServer, PacketSplitter=null, PacketDecoder=class net.minecraft.network.PacketDecoder, EnumProtocolDirection=null, PacketPrepender=null, PacketEncoder=class net.minecraft.network.PacketEncoder, NetworkManagerServer=null, NetworkManager=null, HandshakeListener=null, PacketListener=interface net.minecraft.network.PacketListener}
# [04:18:26 INFO]: failed to get ServerConnection from Minecraft Server
# [04:18:26 INFO]: connecting to minecraft server at localhost/127.0.0.1:25565
# [04:18:26 INFO]: connected to local minecraft server
# [04:18:26 INFO]: jime_de_bayuwu joined the game
# [04:18:26 INFO]: jime_de_bayuwu[/127.0.0.1:43436] logged in with entity id 34170 at ([world]13.59618168939263, 75.0, -10.300000011920929)
# [04:18:36 INFO]: Gabi_21 has made the advancement [The Parrots and the Bats]
# [04:18:36 WARN]: UUID of added entity already exists: Cow['Cow'/34229, l='ServerLevel[world]', x=-0.42, y=79.00, z=-44.46]
# [04:18:38 WARN]: UUID of added entity already exists: Cow['Cow'/34233, l='ServerLevel[world]', x=0.88, y=79.00, z=-46.63]
# [04:18:58 INFO]: <jime_de_bayuwu> perodon bb
# [04:19:06 INFO]: <Gabi_21> relax
# [04:19:17 WARN]: An exceptionCaught() event was fired, and it reached at the tail of the pipeline. It usually means the last handler in the pipeline did not handle the exception.
# java.net.SocketException: Connection reset
# 	at sun.nio.ch.SocketChannelImpl.throwConnectionReset(SocketChannelImpl.java:401) ~[?:?]
# 	at sun.nio.ch.SocketChannelImpl.read(SocketChannelImpl.java:434) ~[?:?]
# 	at io.netty.buffer.PooledByteBuf.setBytes(PooledByteBuf.java:258) ~[netty-buffer-4.1.82.Final.jar%23166!/:4.1.82.Final]
# 	at io.netty.buffer.AbstractByteBuf.writeBytes(AbstractByteBuf.java:1132) ~[netty-buffer-4.1.82.Final.jar%23166!/:4.1.82.Final]
# 	at io.netty.channel.socket.nio.NioSocketChannel.doReadBytes(NioSocketChannel.java:357) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:151) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:788) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:724) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:650) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:562) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997) ~[netty-common-4.1.82.Final.jar%23168!/:4.1.82.Final]
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74) ~[netty-common-4.1.82.Final.jar%23168!/:4.1.82.Final]
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30) ~[netty-common-4.1.82.Final.jar%23168!/:4.1.82.Final]
# 	at java.lang.Thread.run(Thread.java:1583) [?:?]
# [04:19:17 WARN]: failed to send data to tunnel
# [04:19:17 WARN]: failed to send data to tunnel
# [04:19:17 WARN]: failed to send data to tunnel
# [04:19:17 INFO]: jime_de_bayuwu lost connection: Disconnected
# [04:19:17 INFO]: jime_de_bayuwu left the game
# [04:19:21 INFO]: got new client: NewClient{connectAddr=209.25.140.181:62995, peerAddr=189.217.208.208:56612, claimAddress=209.25.140.2:43264, claimToken=[44, 0, 60, -47, 25, -116, -75, -10, 19, -67, -39, -48, -48, -35, 36, -114, -27, -108, -66, -87, 0, 101, -17, -41, -55, 0, 0, 0, 0, 0, 7, 35, 103, 0, 0, 0, 0, 0, 47, 48, 44, 34, -66, -87, 0, 0, 0, 0, 0, 5, 0, 0, 0, 0, 0, 0, 0, 1, 0, 1, 81, -103, 4, 78, 72, 31, 120, -126, 39, -22, -105, -92, 32, -94, 28, 98], tunnelServerId=1, dataCenterId=5}
# [04:19:21 INFO]: starting tcp tunnel for client
# [04:19:21 INFO]: start connection to /209.25.140.2:43264 to claim client
# [04:19:21 INFO]: connected to tunnel server, sending claim token
# [04:19:21 INFO]: claim token sent
# [04:19:21 INFO]: connection to tunnel server has been established
# [04:19:21 INFO]: Reflect: ReflectionHelper{ServerConnection=null, LegacyPingHandler=null, MinecraftServer=class net.minecraft.server.MinecraftServer, PacketSplitter=null, PacketDecoder=class net.minecraft.network.PacketDecoder, EnumProtocolDirection=null, PacketPrepender=null, PacketEncoder=class net.minecraft.network.PacketEncoder, NetworkManagerServer=null, NetworkManager=null, HandshakeListener=null, PacketListener=interface net.minecraft.network.PacketListener}
# [04:19:21 INFO]: failed to get ServerConnection from Minecraft Server
# [04:19:21 INFO]: connecting to minecraft server at localhost/127.0.0.1:25565
# [04:19:21 INFO]: connected to local minecraft server
# [04:19:21 INFO]: jime_de_bayuwu joined the game
# [04:19:21 INFO]: jime_de_bayuwu[/127.0.0.1:59552] logged in with entity id 34395 at ([world]13.519340304371235, 75.0, -10.209497202659138)
# [04:19:35 INFO]: <Gabi_21> seguro el internet
# [04:19:51 WARN]: failed to send data to tunnel
# [04:19:51 WARN]: failed to send data to tunnel
# [04:19:51 WARN]: failed to send data to tunnel
# [04:19:51 WARN]: failed to send data to tunnel
# [04:19:51 WARN]: failed to send data to tunnel
# [04:19:51 INFO]: jime_de_bayuwu lost connection: Disconnected
# [04:19:51 WARN]: failed to send data to tunnel
# [04:19:51 WARN]: failed to send data to tunnel
# [04:19:51 WARN]: failed to send data to tunnel
# [04:19:51 WARN]: failed to send data to tunnel
# [04:19:51 WARN]: failed to send data to tunnel
# [04:19:51 WARN]: failed to send data to tunnel
# [04:19:51 WARN]: failed to send data to tunnel
# [04:19:51 WARN]: failed to send data to tunnel
# [04:19:51 WARN]: failed to send data to tunnel
# [04:19:51 WARN]: failed to send data to tunnel
# [04:19:51 WARN]: failed to send data to tunnel
# [04:19:51 WARN]: failed to send data to tunnel
# [04:19:51 WARN]: failed to send data to tunnel
# [04:19:51 WARN]: failed to send data to tunnel
# [04:19:51 WARN]: failed to send data to tunnel
# ...
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 WARN]: failed to send data to tunnel
# [04:20:20 INFO]: jime_de_bayuwu lost connection: Disconnected
# [04:20:20 INFO]: jime_de_bayuwu left the game
# [04:20:30 INFO]: got new client: NewClient{connectAddr=209.25.140.181:62995, peerAddr=189.217.208.208:56617, claimAddress=209.25.140.2:43264, claimToken=[44, 0, 60, -47, 25, -116, -75, -10, 19, -67, -39, -48, -48, -35, 41, 90, -92, 78, 113, -87, 0, 101, -17, -40, 14, 0, 0, 0, 0, 0, 7, 35, 103, 0, 0, 0, 0, 0, 47, 48, 44, 78, 113, -87, 0, 0, 0, 0, 0, 5, 0, 0, 0, 0, 0, 0, 0, 1, 0, 1, -44, -122, -45, -38, -24, 119, 17, 120, 55, -4, -12, 92, -77, 111, 116, 106], tunnelServerId=1, dataCenterId=5}
# [04:20:30 INFO]: starting tcp tunnel for client
# [04:20:30 INFO]: start connection to /209.25.140.2:43264 to claim client
# [04:20:30 INFO]: connected to tunnel server, sending claim token
# [04:20:30 INFO]: claim token sent
# [04:20:30 INFO]: connection to tunnel server has been established
# [04:20:30 INFO]: Reflect: ReflectionHelper{ServerConnection=null, LegacyPingHandler=null, MinecraftServer=class net.minecraft.server.MinecraftServer, PacketSplitter=null, PacketDecoder=class net.minecraft.network.PacketDecoder, EnumProtocolDirection=null, PacketPrepender=null, PacketEncoder=class net.minecraft.network.PacketEncoder, NetworkManagerServer=null, NetworkManager=null, HandshakeListener=null, PacketListener=interface net.minecraft.network.PacketListener}
# [04:20:30 INFO]: failed to get ServerConnection from Minecraft Server
# [04:20:30 INFO]: connecting to minecraft server at localhost/127.0.0.1:25565
# [04:20:30 INFO]: connected to local minecraft server
# [04:20:30 INFO]: jime_de_bayuwu joined the game
# [04:20:30 INFO]: jime_de_bayuwu[/127.0.0.1:58854] logged in with entity id 34546 at ([world]13.519340304371235, 75.0, -10.209497202659138)
# [04:20:43 WARN]: An exceptionCaught() event was fired, and it reached at the tail of the pipeline. It usually means the last handler in the pipeline did not handle the exception.
# java.net.SocketException: Connection reset
# 	at sun.nio.ch.SocketChannelImpl.throwConnectionReset(SocketChannelImpl.java:401) ~[?:?]
# 	at sun.nio.ch.SocketChannelImpl.read(SocketChannelImpl.java:434) ~[?:?]
# 	at io.netty.buffer.PooledByteBuf.setBytes(PooledByteBuf.java:258) ~[netty-buffer-4.1.82.Final.jar%23166!/:4.1.82.Final]
# 	at io.netty.buffer.AbstractByteBuf.writeBytes(AbstractByteBuf.java:1132) ~[netty-buffer-4.1.82.Final.jar%23166!/:4.1.82.Final]
# 	at io.netty.channel.socket.nio.NioSocketChannel.doReadBytes(NioSocketChannel.java:357) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:151) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:788) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:724) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:650) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:562) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997) ~[netty-common-4.1.82.Final.jar%23168!/:4.1.82.Final]
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74) ~[netty-common-4.1.82.Final.jar%23168!/:4.1.82.Final]
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30) ~[netty-common-4.1.82.Final.jar%23168!/:4.1.82.Final]
# 	at java.lang.Thread.run(Thread.java:1583) [?:?]
# [04:20:43 WARN]: failed to send data to tunnel
# [04:20:43 INFO]: jime_de_bayuwu lost connection: Disconnected
# [04:20:43 INFO]: jime_de_bayuwu left the game
# [04:20:47 INFO]: got new client: NewClient{connectAddr=209.25.140.181:62995, peerAddr=189.217.208.208:56622, claimAddress=209.25.140.2:43264, claimToken=[44, 0, 60, -47, 25, -116, -75, -10, 19, -67, -39, -48, -48, -35, 46, 28, -87, -62, 7, -87, 0, 101, -17, -40, 32, 0, 0, 0, 0, 0, 7, 35, 103, 0, 0, 0, 0, 0, 47, 48, 44, -75, 7, -87, 0, 0, 0, 0, 0, 5, 0, 0, 0, 0, 0, 0, 0, 1, 0, 1, 107, -32, -62, -22, 76, 104, 10, -82, -53, 15, -39, 121, 106, 33, 23, -43], tunnelServerId=1, dataCenterId=5}
# [04:20:47 INFO]: starting tcp tunnel for client
# [04:20:47 INFO]: start connection to /209.25.140.2:43264 to claim client
# [04:20:48 INFO]: connected to tunnel server, sending claim token
# [04:20:48 INFO]: claim token sent
# [04:20:48 INFO]: connection to tunnel server has been established
# [04:20:48 INFO]: Reflect: ReflectionHelper{ServerConnection=null, LegacyPingHandler=null, MinecraftServer=class net.minecraft.server.MinecraftServer, PacketSplitter=null, PacketDecoder=class net.minecraft.network.PacketDecoder, EnumProtocolDirection=null, PacketPrepender=null, PacketEncoder=class net.minecraft.network.PacketEncoder, NetworkManagerServer=null, NetworkManager=null, HandshakeListener=null, PacketListener=interface net.minecraft.network.PacketListener}
# [04:20:48 INFO]: failed to get ServerConnection from Minecraft Server
# [04:20:48 INFO]: connecting to minecraft server at localhost/127.0.0.1:25565
# [04:20:48 INFO]: connected to local minecraft server
# [04:20:48 INFO]: jime_de_bayuwu joined the game
# [04:20:48 INFO]: jime_de_bayuwu[/127.0.0.1:51098] logged in with entity id 34579 at ([world]13.272671151333734, 75.0, -14.682612373632198)
# [04:21:12 WARN]: An exceptionCaught() event was fired, and it reached at the tail of the pipeline. It usually means the last handler in the pipeline did not handle the exception.
# java.net.SocketException: Connection reset
# 	at sun.nio.ch.SocketChannelImpl.throwConnectionReset(SocketChannelImpl.java:401) ~[?:?]
# 	at sun.nio.ch.SocketChannelImpl.read(SocketChannelImpl.java:434) ~[?:?]
# 	at io.netty.buffer.PooledByteBuf.setBytes(PooledByteBuf.java:258) ~[netty-buffer-4.1.82.Final.jar%23166!/:4.1.82.Final]
# 	at io.netty.buffer.AbstractByteBuf.writeBytes(AbstractByteBuf.java:1132) ~[netty-buffer-4.1.82.Final.jar%23166!/:4.1.82.Final]
# 	at io.netty.channel.socket.nio.NioSocketChannel.doReadBytes(NioSocketChannel.java:357) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:151) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:788) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:724) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:650) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:562) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997) ~[netty-common-4.1.82.Final.jar%23168!/:4.1.82.Final]
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74) ~[netty-common-4.1.82.Final.jar%23168!/:4.1.82.Final]
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30) ~[netty-common-4.1.82.Final.jar%23168!/:4.1.82.Final]
# 	at java.lang.Thread.run(Thread.java:1583) [?:?]
# [04:21:12 WARN]: failed to send data to tunnel
# [04:21:12 WARN]: failed to send data to tunnel
# [04:21:12 INFO]: jime_de_bayuwu lost connection: Disconnected
# [04:21:12 INFO]: jime_de_bayuwu left the game
# [04:21:17 INFO]: Gabi_21 issued server command: /give Gabi_21 minecraft:carrot 61
# [04:21:17 INFO]: [Gabi_21: Gave 61 [Carrot] to Gabi_21]
# [04:21:18 INFO]: got new client: NewClient{connectAddr=209.25.140.181:62995, peerAddr=189.217.208.208:56626, claimAddress=209.25.140.2:43264, claimToken=[44, 0, 60, -47, 25, -116, -75, -10, 19, -67, -39, -48, -48, -35, 50, -35, 95, -28, -122, -87, 0, 101, -17, -40, 62, 0, 0, 0, 0, 0, 7, 35, 103, 0, 0, 0, 0, 0, 47, 48, 44, -128, -122, -87, 0, 0, 0, 0, 0, 5, 0, 0, 0, 0, 0, 0, 0, 1, 0, 1, 75, -101, 1, -24, 42, -54, -57, 16, 69, 108, 18, -26, 95, -112, 87, 35], tunnelServerId=1, dataCenterId=5}
# [04:21:18 INFO]: starting tcp tunnel for client
# [04:21:18 INFO]: start connection to /209.25.140.2:43264 to claim client
# [04:21:18 INFO]: connected to tunnel server, sending claim token
# [04:21:18 INFO]: claim token sent
# [04:21:18 INFO]: connection to tunnel server has been established
# [04:21:18 INFO]: Reflect: ReflectionHelper{ServerConnection=null, LegacyPingHandler=null, MinecraftServer=class net.minecraft.server.MinecraftServer, PacketSplitter=null, PacketDecoder=class net.minecraft.network.PacketDecoder, EnumProtocolDirection=null, PacketPrepender=null, PacketEncoder=class net.minecraft.network.PacketEncoder, NetworkManagerServer=null, NetworkManager=null, HandshakeListener=null, PacketListener=interface net.minecraft.network.PacketListener}
# [04:21:18 INFO]: failed to get ServerConnection from Minecraft Server
# [04:21:18 INFO]: connecting to minecraft server at localhost/127.0.0.1:25565
# [04:21:18 INFO]: connected to local minecraft server
# [04:21:18 INFO]: jime_de_bayuwu joined the game
# [04:21:18 INFO]: jime_de_bayuwu[/127.0.0.1:44014] logged in with entity id 34627 at ([world]-10.414593288803525, 80.26999998092651, -27.932322698017874)
# [04:21:33 INFO]: <jime_de_bayuwu> bb duerme
# [04:21:36 INFO]: send keep alive
# [04:21:42 WARN]: An exceptionCaught() event was fired, and it reached at the tail of the pipeline. It usually means the last handler in the pipeline did not handle the exception.
# java.net.SocketException: Connection reset
# 	at sun.nio.ch.SocketChannelImpl.throwConnectionReset(SocketChannelImpl.java:401) ~[?:?]
# 	at sun.nio.ch.SocketChannelImpl.read(SocketChannelImpl.java:434) ~[?:?]
# 	at io.netty.buffer.PooledByteBuf.setBytes(PooledByteBuf.java:258) ~[netty-buffer-4.1.82.Final.jar%23166!/:4.1.82.Final]
# 	at io.netty.buffer.AbstractByteBuf.writeBytes(AbstractByteBuf.java:1132) ~[netty-buffer-4.1.82.Final.jar%23166!/:4.1.82.Final]
# 	at io.netty.channel.socket.nio.NioSocketChannel.doReadBytes(NioSocketChannel.java:357) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:151) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:788) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:724) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:650) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:562) ~[netty-transport-4.1.82.Final.jar%23171!/:4.1.82.Final]
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997) ~[netty-common-4.1.82.Final.jar%23168!/:4.1.82.Final]
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74) ~[netty-common-4.1.82.Final.jar%23168!/:4.1.82.Final]
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30) ~[netty-common-4.1.82.Final.jar%23168!/:4.1.82.Final]
# 	at java.lang.Thread.run(Thread.java:1583) [?:?]
# [04:21:42 WARN]: failed to send data to tunnel
# [04:21:42 WARN]: failed to send data to tunnel
# [04:21:42 WARN]: failed to send data to tunnel
# [04:21:42 INFO]: jime_de_bayuwu lost connection: Disconnected
# [04:21:42 INFO]: jime_de_bayuwu left the game
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [04:23:33 INFO]: Gabi_21 issued server command: /give Gabi_21 minecraft:coal 61
# [04:23:33 INFO]: [Gabi_21: Gave 61 [Coal] to Gabi_21]
# [04:25:06 INFO]: Gabi_21 issued server command: /give Gabi_21 minecraft:bone_meal 64
# [04:25:06 INFO]: [Gabi_21: Gave 64 [Bone Meal] to Gabi_21]
# [04:25:37 INFO]: send keep alive
# [04:26:15 WARN]: UUID of added entity already exists: Cow['Cow'/35323, l='ServerLevel[world]', x=0.27, y=79.00, z=-42.04]
# [04:26:16 WARN]: UUID of added entity already exists: Cow['Cow'/35348, l='ServerLevel[world]', x=0.26, y=79.00, z=-44.95]
# [04:27:19 WARN]: failed to send data to tunnel
# [04:27:19 WARN]: failed to send data to tunnel
# [04:27:19 WARN]: failed to send data to tunnel
# [04:27:19 WARN]: failed to send data to tunnel
# [04:27:19 WARN]: failed to send data to tunnel
# [04:27:19 WARN]: failed to send data to tunnel
# [04:27:19 WARN]: failed to send data to tunnel
# [04:27:19 WARN]: failed to send data to tunnel
# [04:27:19 INFO]: Gabi_21 lost connection: Disconnected
# [04:27:19 INFO]: Gabi_21 left the game
# [04:27:20 INFO]: got new client: NewClient{connectAddr=209.25.140.181:62995, peerAddr=181.236.105.152:12496, claimAddress=209.25.140.2:43784, claimToken=[44, 0, 60, -47, 25, -116, -75, -10, 19, -75, -20, 105, -104, 48, -48, 54, 64, -42, -64, -85, 8, 101, -17, -39, -88, 0, 0, 0, 0, 0, 7, 35, 103, 0, 0, 0, 0, 0, 47, 48, 44, 108, -64, -85, 8, 0, 0, 0, 0, 6, 0, 0, 0, 0, 0, 0, 0, 1, 0, 1, 83, 68, 54, -120, -124, -114, 125, -90, -94, 91, -114, -84, -22, 99, 104, -18], tunnelServerId=1, dataCenterId=6}
# [04:27:20 INFO]: starting tcp tunnel for client
# [04:27:20 INFO]: start connection to /209.25.140.2:43784 to claim client
# [04:27:20 INFO]: connected to tunnel server, sending claim token
# [04:27:20 INFO]: claim token sent
# [04:27:20 INFO]: connection to tunnel server has been established
# [04:27:20 INFO]: Reflect: ReflectionHelper{ServerConnection=null, LegacyPingHandler=null, MinecraftServer=class net.minecraft.server.MinecraftServer, PacketSplitter=null, PacketDecoder=class net.minecraft.network.PacketDecoder, EnumProtocolDirection=null, PacketPrepender=null, PacketEncoder=class net.minecraft.network.PacketEncoder, NetworkManagerServer=null, NetworkManager=null, HandshakeListener=null, PacketListener=interface net.minecraft.network.PacketListener}
# [04:27:20 INFO]: failed to get ServerConnection from Minecraft Server
# [04:27:20 INFO]: connecting to minecraft server at localhost/127.0.0.1:25565
# [04:27:20 INFO]: connected to local minecraft server
# >
# >=>
# >[04:27:25 INFO]: Stopping server
# [04:27:25 INFO]: [Mohist] Disabling Mohist v1.20.1
# [04:27:25 INFO]: Saving players
# [04:27:25 INFO]: Saving worlds
